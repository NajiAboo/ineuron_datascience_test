# %%
import pandas as pd

# %%
import json

# %%
import pandas as pd
import json
import requests

url = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"
response = requests.get(url)
data = json.loads(response.text)

df = pd.DataFrame(data)

# %%
# Assuming your JSON objects have nested structures
df_flattened = pd.json_normalize(df.to_dict("records"))

# %%
df_flattened.to_excel("output_final.xls")
# Out:
# /tmp/ipykernel_114106/3350176920.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df_flattened.to_excel("output_final.xls")

# %%
df_flattened
# Out:
#      pokemon.id pokemon.num pokemon.name  \
# 0             1         001    Bulbasaur
# 1             2         002      Ivysaur
# 2             3         003     Venusaur
# 3             4         004   Charmander
# 4             5         005   Charmeleon
# ..          ...         ...          ...
# 146         147         147      Dratini
# 147         148         148    Dragonair
# 148         149         149    Dragonite
# 149         150         150       Mewtwo
# 150         151         151          Mew
#
#                                           pokemon.img      pokemon.type  \
# 0    http://www.serebii.net/pokemongo/pokemon/001.png   [Grass, Poison]
# 1    http://www.serebii.net/pokemongo/pokemon/002.png   [Grass, Poison]
# 2    http://www.serebii.net/pokemongo/pokemon/003.png   [Grass, Poison]
# 3    http://www.serebii.net/pokemongo/pokemon/004.png            [Fire]
# 4    http://www.serebii.net/pokemongo/pokemon/005.png            [Fire]
# ..                                                ...               ...
# 146  http://www.serebii.net/pokemongo/pokemon/147.png          [Dragon]
# 147  http://www.serebii.net/pokemongo/pokemon/148.png          [Dragon]
# 148  http://www.serebii.net/pokemongo/pokemon/149.png  [Dragon, Flying]
# 149  http://www.serebii.net/pokemongo/pokemon/150.png         [Psychic]
# 150  http://www.serebii.net/pokemongo/pokemon/151.png         [Psychic]
#
#     pokemon.height pokemon.weight     pokemon.candy  pokemon.candy_count  \
# 0           0.71 m         6.9 kg   Bulbasaur Candy                 25.0
# 1           0.99 m        13.0 kg   Bulbasaur Candy                100.0
# 2           2.01 m       100.0 kg   Bulbasaur Candy                  NaN
# 3           0.61 m         8.5 kg  Charmander Candy                 25.0
# 4           1.09 m        19.0 kg  Charmander Candy                100.0
# ..             ...            ...               ...                  ...
# 146         1.80 m         3.3 kg     Dratini Candy                 25.0
# 147         3.99 m        16.5 kg     Dratini Candy                100.0
# 148         2.21 m       210.0 kg     Dratini Candy                  NaN
# 149         2.01 m       122.0 kg              None                  NaN
# 150         0.41 m         4.0 kg              None                  NaN
#
#      pokemon.egg  pokemon.spawn_chance  pokemon.avg_spawns pokemon.spawn_time  \
# 0           2 km                0.6900               69.00              20:00
# 1    Not in Eggs                0.0420                4.20              07:00
# 2    Not in Eggs                0.0170                1.70              11:30
# 3           2 km                0.2530               25.30              08:45
# 4    Not in Eggs                0.0120                1.20              19:00
# ..           ...                   ...                 ...                ...
# 146        10 km                0.3000               30.00              06:41
# 147  Not in Eggs                0.0200                2.00              11:57
# 148  Not in Eggs                0.0011                0.11              23:38
# 149  Not in Eggs                0.0000                0.00                N/A
# 150  Not in Eggs                0.0000                0.00                N/A
#
#     pokemon.multipliers            pokemon.weaknesses  \
# 0                [1.58]  [Fire, Ice, Flying, Psychic]
# 1            [1.2, 1.6]  [Fire, Ice, Flying, Psychic]
# 2                  None  [Fire, Ice, Flying, Psychic]
# 3                [1.65]         [Water, Ground, Rock]
# 4                [1.79]         [Water, Ground, Rock]
# ..                  ...                           ...
# 146        [1.83, 1.84]          [Ice, Dragon, Fairy]
# 147              [2.05]          [Ice, Dragon, Fairy]
# 148                None    [Ice, Rock, Dragon, Fairy]
# 149                None            [Bug, Ghost, Dark]
# 150                None            [Bug, Ghost, Dark]
#
#                                 pokemon.next_evolution  \
# 0    [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...
# 1                 [{'num': '003', 'name': 'Venusaur'}]
# 2                                                  NaN
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4                [{'num': '006', 'name': 'Charizard'}]
# ..                                                 ...
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...
# 147              [{'num': '149', 'name': 'Dragonite'}]
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
#
#                                 pokemon.prev_evolution
# 0                                                  NaN
# 1                [{'num': '001', 'name': 'Bulbasaur'}]
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3                                                  NaN
# 4               [{'num': '004', 'name': 'Charmander'}]
# ..                                                 ...
# 146                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...
# 149                                                NaN
# 150                                                NaN
#
# [151 rows x 17 columns]
